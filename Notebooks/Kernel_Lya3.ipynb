# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow_probability as tfp
import tensorflow as tf
import tensorflow.keras.backend as kb
tfd = tfp.distributions

seed = 1
np.random.seed(seed)

plt.rcParams['figure.figsize'] = (8,8)
plt.rcParams['figure.dpi'] = 80

# %%
def build_kernel_matrix(num_datapoints, input_datapoints, kernel_fn, input_rhs):
    """
    Constructs the full kernel matrix element by element
    :return: tf.Tensor, (num_points, num_points)
    """
    kernel_mat = tf.Variable(tf.zeros((num_datapoints, num_datapoints), dtype=tf.float32))

    for i in range(num_datapoints):
        for j in range(i, num_datapoints):
            inputs_i = tf.expand_dims(tf.constant(input_datapoints[i]), 0)  # (1, d)
            inputs_j = tf.expand_dims(tf.constant(input_datapoints[j]), 0)  # (1, d)
            print('inputs: {}'.format(inputs_i.shape))
            with tf.GradientTape() as tape1:
                tape1.watch(inputs_i)
                with tf.GradientTape() as tape2:
                    tape2.watch(inputs_j)
                    kernel_output = kernel_fn.apply(tf.expand_dims(inputs_i, 0), tf.expand_dims(inputs_j, 0))  # (1, 1, 1)
                    # kernel_output = kernel_fn(tf.expand_dims(inputs_i, 0), tf.expand_dims(inputs_j, 0))  # (1, 1, 1)
                    kernel_output = tf.squeeze(kernel_output)  # scalar
                    print('kernel output: {}'.format(kernel_output))
                grads2 = tape2.gradient(kernel_output, inputs_j)  # (d,)
                print(grads2)
                first_inner_product = tf.reduce_sum(grads2 * input_rhs[j])  # scalar
                print(first_inner_product)
            grads1 = tape1.gradient(first_inner_product, inputs_i)  # (d,) # this becomes nan when taking gradient of value 0 (when x=y)
            # grads1 = tf.where(tf.math.is_nan(grads1), tf.zeros_like(grads1), grads1) 
            second_inner_product = tf.reduce_sum(grads1 * input_rhs[i])  # scalar
            kernel_mat[i, j].assign(second_inner_product)
            if i != j:
                kernel_mat[j, i].assign(second_inner_product)
    # kernel_mat = tf.where(tf.math.is_nan(kernel_mat), tf.ones_like(kernel_mat), kernel_mat) 
    K = tf.constant(kernel_mat.numpy())
    return K

# %%
def build_lyapunov_function2(xs, a, num_datapoints, input_datapoints, kernel_fn, input_rhs):
    mat = tf.Variable(tf.zeros((num_datapoints,), dtype=tf.float32))
    all_s = tf.Variable(tf.zeros((xs.shape[0],), dtype=tf.float32))
    for i in range(xs.shape[0]):
        for j in range(num_datapoints):
            inputs_i = tf.expand_dims(tf.constant(xs[i]), 0)  # (1, d)
            inputs_j = tf.expand_dims(tf.constant(input_datapoints[j]), 0)  # (1, d)
            # print(inputs_i.shape)
            with tf.GradientTape() as tape:
                tape.watch(inputs_j)
                kernel_output = kernel_fn.apply(tf.expand_dims(inputs_i, 0), tf.expand_dims(inputs_j, 0))  # (1, 1, 1)
                # kernel_output = kernel_fn(tf.expand_dims(inputs_i, 0), tf.expand_dims(inputs_j, 0))  # (1, 1, 1)
                
                # print(kernel_output.shape)
                kernel_output = tf.squeeze(kernel_output)  # scalar
            grads = tape.gradient(kernel_output, inputs_j)  # (d,)
            inner_product = tf.reduce_sum(grads * input_rhs[j])  # scalar
            mat[j].assign(inner_product)
        all_lambda = tf.constant(mat.numpy()) # (num_datapoints,)
        s = tf.reduce_sum(a * all_lambda) # scalar
        all_s[i].assign(s)
    solution = tf.constant(all_s.numpy()) # (len(x),)
    return solution

# %%
# def build_lyapunov_function(x, a, num_datapoints, input_datapoints, kernel_fn, input_rhs):
#     all_s = tf.Variable(tf.zeros((num_datapoints,), dtype=tf.float32))
#     for i in range(num_datapoints):
#         inputs_i = tf.expand_dims(tf.constant(input_datapoints[i]), 0)  # (1, d)
#         with tf.GradientTape() as tape:
#             tape.watch(inputs_i)
#             kernel_output = kernel_fn.apply(tf.expand_dims(x, 0), tf.expand_dims(inputs_i, 0))  # (1, 1, 1)
#             kernel_output = tf.squeeze(kernel_output)  # scalar
#         grads = tape.gradient(kernel_output, inputs_i)  # (d,)
#         inner_product = tf.reduce_sum(grads * input_rhs[i]) # scalar
#         all_s[i].assign(inner_product)
#     s = tf.reduce_sum(a * all_s)
#     return s

# %%
def safe_norm(x, epsilon=1e-12, axis=None):
  return tf.sqrt(tf.reduce_sum(x ** 2, axis=axis) + epsilon)

def Gaussian_Kernel(x, y):
    # print((tf.norm(x-y, ord = 2, axis=2)).shape)
    exponent = - 1/2 * tf.square(tf.norm(x-y, ord = 'euclidean', axis=0))
    # print(exponent)
    # exponent = - 1/2 * tf.square(safe_norm(x-y, axis=2))
    # print(exponent.shape)
    kernel = tf.expand_dims(tf.exp(exponent), 0)
    # kernel = tf.where(tf.math.is_nan(kernel), tf.ones_like(kernel), kernel) 
    return kernel

# %%
tf.squeeze(tf.ones((1,2)))
# Out:
# <tf.Tensor: shape=(2,), dtype=float32, numpy=array([1., 1.], dtype=float32)>

# %%
Gaussian_Kernel(data_points[0][tf.newaxis, tf.newaxis, ...], data_points[0][tf.newaxis, tf.newaxis, ...])
# Out:
# <tf.Tensor: shape=(1, 1, 2), dtype=float32, numpy=array([[[1., 1.]]], dtype=float32)>

# %%
g_kernel = tfp.math.psd_kernels.ExponentiatedQuadratic()
n_y = 90
dim = 2
bounds = [1.6, 4]
# bounds = [2,2]
omega_domain = np.array([np.random.uniform(-bounds[0], bounds[0],n_y), 
                            np.random.uniform(-bounds[1],bounds[1],n_y)]).T

x = np.linspace(-bounds[0], bounds[0], n_y)
y = np.linspace(-bounds[1], bounds[1], n_y)

data_points = tf.transpose(tf.constant(np.array([x,y]), tf.float32))
                   


# van poole equation
def vf(x):
    y = [-x[:,1], x[:,0] - (1-x[:,0]**2)*x[:,1]]
    return y

# def vf(x):
#     y1s = []
#     y2s = []
#     for i in x[:,0]:
#         if i != 0:
#             y1 = - i**2*dim / np.sin(i)
#         else:
#             y1 = 0.
#         y1s.append(y1)
#     for i in x[:,1]:
#         if i != 0:
#             y2 = - i**2*dim / np.sin(i)
#         else:
#             y2 = 0.
#         y2s.append(y2)
#     return [y1s, y2s]



# data_points = tf.constant(omega_domain, dtype=tf.float32)
input_RHS =  tf.transpose(tf.convert_to_tensor(vf(data_points), dtype=tf.float32))


beta = -tf.square(tf.norm(data_points, ord = 2, axis=1))[..., tf.newaxis]
A = build_kernel_matrix(n_y, data_points, g_kernel, input_RHS)

alphas = tf.linalg.solve(A, beta)
# Out:
# inputs: (1, 2)
# kernel output: 1.0
# tf.Tensor([[0. 0.]], shape=(1, 2), dtype=float32)
# tf.Tensor(0.0, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.9953246712684631
# tf.Tensor([[-0.03578697 -0.08946736]], shape=(1, 2), dtype=float32)
# tf.Tensor(0.50593317, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.9814295172691345
# tf.Tensor([[-0.07057474 -0.17643672]], shape=(1, 2), dtype=float32)
# tf.Tensor(0.8998667, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.9587005972862244
# tf.Tensor([[-0.10341045 -0.25852594]], shape=(1, 2), dtype=float32)
# tf.Tensor(1.1827903, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.9277616739273071
# tf.Tensor([[-0.13343094 -0.33357716]], shape=(1, 2), dtype=float32)
# tf.Tensor(1.3606527, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.8894456624984741
# tf.Tensor([[-0.15990041 -0.39975077]], shape=(1, 2), dtype=float32)
# tf.Tensor(1.4435222, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.8447571992874146
# tf.Tensor([[-0.18223973 -0.4555995 ]], shape=(1, 2), dtype=float32)
# tf.Tensor(1.44456, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.7948295474052429
# tf.Tensor([[-0.20004697 -0.50011754]], shape=(1, 2), dtype=float32)
# tf.Tensor(1.3788955, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.7408761978149414
# tf.Tensor([[-0.21310596 -0.532765  ]], shape=(1, 2), dtype=float32)
# tf.Tensor(1.2625213, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.6841428875923157
# tf.Tensor([[-0.22138558 -0.55346394]], shape=(1, 2), dtype=float32)
# tf.Tensor(1.1112511, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.6258605122566223
# tf.Tensor([[-0.22502851 -0.5625713 ]], shape=(1, 2), dtype=float32)
# tf.Tensor(0.93984336, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.5672021508216858
# tf.Tensor([[-0.22433166 -0.5608291 ]], shape=(1, 2), dtype=float32)
# tf.Tensor(0.76131696, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.5092460513114929
# tf.Tensor([[-0.21971968 -0.5492991 ]], shape=(1, 2), dtype=float32)
# tf.Tensor(0.58649, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.4529467225074768
# tf.Tensor([[-0.21171446 -0.529286  ]], shape=(1, 2), dtype=float32)
# tf.Tensor(0.4237393, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.3991132080554962
# tf.Tensor([[-0.20090193 -0.5022548 ]], shape=(1, 2), dtype=float32)
# tf.Tensor(0.27896786, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.3483971357345581
# tf.Tensor([[-0.18789957 -0.4697489 ]], shape=(1, 2), dtype=float32)
# tf.Tensor(0.15574023, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.30128857493400574
# tf.Tensor([[-0.17332557 -0.43331388]], shape=(1, 2), dtype=float32)
# tf.Tensor(0.055557787, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.25811904668807983
# tf.Tensor([[-0.15777165 -0.39442915]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.021786809, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.21907219290733337
# tf.Tensor([[-0.14178157 -0.3544539 ]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.07780808, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.18419761955738068
# tf.Tensor([[-0.12583388 -0.3145847 ]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.11492348, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.1534300148487091
# tf.Tensor([[-0.1103317  -0.27582926]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.13607788, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.1266094297170639
# tf.Tensor([[-0.09559724 -0.23899308]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.14441936, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.10350263863801956
# tf.Tensor([[-0.08187176 -0.20467937]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.143038, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.08382362872362137
# tf.Tensor([[-0.06931932 -0.17329828]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.13477556, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.06725287437438965
# tf.Tensor([[-0.05803394 -0.14508484]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.12210157, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.05345458537340164
# tf.Tensor([[-0.04804907 -0.12012266]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.107050106, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.042090922594070435
# tf.Tensor([[-0.03934792 -0.09836979]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.09120486, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.03283384069800377
# tf.Tensor([[-0.03187465 -0.07968662]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.07572256, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.025373732671141624
# tf.Tensor([[-0.02554479 -0.06386197]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.061380595, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.01942569576203823
# tf.Tensor([[-0.02025511 -0.05063777]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.04863912, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.014733241870999336
# tf.Tensor([[-0.01589204 -0.03973009]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.0377082, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.01107004564255476
# tf.Tensor([[-0.01233875 -0.03084687]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.02861289, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.00824006088078022
# tf.Tensor([[-0.0094807  -0.02370175]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.021251818, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.006076321005821228
# tf.Tensor([[-0.00720966 -0.01802414]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.015446268, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.004438954405486584
# tf.Tensor([[-0.0054265  -0.01356624]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.01097916, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.0032125532161444426
# tf.Tensor([[-0.00404276 -0.01010691]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.0076236655, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.0023032943718135357
# tf.Tensor([[-0.00298134 -0.00745336]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.005162801, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.001635981141589582
# tf.Tensor([[-0.00217641 -0.00544102]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.0034013633, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.001151160802692175
# tf.Tensor([[-0.00157282 -0.00393206]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.002171899, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.000802460708655417
# tf.Tensor([[-0.00112525 -0.00281312]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.0013363692, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.0005541677819564939
# tf.Tensor([[-0.00079701 -0.00199251]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.0007848616, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.00037912989500910044
# tf.Tensor([[-0.0005589  -0.00139724]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.00043262064, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.0002569592616055161
# tf.Tensor([[-0.00038804 -0.00097009]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.00021623715, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.00017253222176805139
# tf.Tensor([[-0.00026675 -0.00066687]], shape=(1, 2), dtype=float32)
# tf.Tensor(-8.9653e-05, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.00011476399231469259
# tf.Tensor([[-0.00018156 -0.0004539 ]], shape=(1, 2), dtype=float32)
# tf.Tensor(-2.039332e-05, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 7.562596874777228e-05
# tf.Tensor([[-0.00012236 -0.0003059 ]], shape=(1, 2), dtype=float32)
# tf.Tensor(1.3743997e-05, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 4.9370300985174254e-05
# tf.Tensor([[-8.1655147e-05 -2.0413788e-04]], shape=(1, 2), dtype=float32)
# tf.Tensor(2.7444146e-05, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 3
], shape=(1, 2), dtype=float32)
# tf.Tensor(-2.3570542e-12, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 9.431159602195024e-14
# tf.Tensor([[-2.712783e-13 -6.781958e-13]], shape=(1, 2), dtype=float32)
# tf.Tensor(-1.3616892e-12, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 4.434998443253631e-14
# tf.Tensor([[-1.2916311e-13 -3.2290777e-13]], shape=(1, 2), dtype=float32)
# tf.Tensor(-7.6521157e-13, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 2.0661039407663707e-14
# tf.Tensor([[-6.0915249e-14 -1.5228811e-13]], shape=(1, 2), dtype=float32)
# tf.Tensor(-4.1988006e-13, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 9.535448839759816e-15
# tf.Tensor([[-2.845635e-14 -7.114088e-14]], shape=(1, 2), dtype=float32)
# tf.Tensor(-2.2556491e-13, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 4.359705261055722e-15
# tf.Tensor([[-1.3167289e-14 -3.2918224e-14]], shape=(1, 2), dtype=float32)
# tf.Tensor(-1.1886958e-13, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 1.974714379713552e-15
# tf.Tensor([[-6.0350822e-15 -1.5087705e-14]], shape=(1, 2), dtype=float32)
# tf.Tensor(-6.154238e-14, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 8.860962538970966e-16
# tf.Tensor([[-2.7399292e-15 -6.8498229e-15]], shape=(1, 2), dtype=float32)
# tf.Tensor(-3.133885e-14, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 3.939024283159065e-16
# tf.Tensor([[-1.2321622e-15 -3.0804056e-15]], shape=(1, 2), dtype=float32)
# tf.Tensor(-1.571076e-14, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 1.7346993884773696e-16
# tf.Tensor([[-5.4886666e-16 -1.3721667e-15]], shape=(1, 2), dtype=float32)
# tf.Tensor(-7.759532e-15, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 7.568142107277137e-17
# tf.Tensor([[-2.4218056e-16 -6.0545137e-16]], shape=(1, 2), dtype=float32)
# tf.Tensor(-3.778017e-15, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 1.0
# tf.Tensor([[0. 0.]], shape=(1, 2), dtype=float32)
# tf.Tensor(0.0, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.9953246712684631
# tf.Tensor([[-0.03578697 -0.08946736]], shape=(1, 2), dtype=float32)
# tf.Tensor(0.45630354, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.9814295172691345
# tf.Tensor([[-0.07057474 -0.17643672]], shape=(1, 2), dtype=float32)
# tf.Tensor(0.80722123, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.9587005972862244
# tf.Tensor([[-0.10341045 -0.25852594]], shape=(1, 2), dtype=float32)
# tf.Tensor(1.0545206, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.9277616739273071
# tf.Tensor([[-0.13343094 -0.33357716]], shape=(1, 2), dtype=float32)
# tf.Tensor(1.2045658, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.8894455432891846
# tf.Tensor([[-0.15990028 -0.39975092]], shape=(1, 2), dtype=float32)
# tf.Tensor(1.2674823, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.8447571992874146
# tf.Tensor([[-0.18223973 -0.4555995 ]], shape=(1, 2), dtype=float32)
# tf.Tensor(1.2561531, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.7948295474052429
# tf.Tensor([[-0.20004697 -0.50011754]], shape=(1, 2), dtype=float32)
# tf.Tensor(1.1851552, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.7408761978149414
# tf.Tensor([[-0.21310596 -0.532765  ]], shape=(1, 2), dtype=float32)
# tf.Tensor(1.0696917, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.6841428875923157
# tf.Tensor([[-0.22138558 -0.55346394]], shape=(1, 2), dtype=float32)
# tf.Tensor(0.9246284, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.6258605122566223
# tf.Tensor([[-0.22502851 -0.5625713 ]], shape=(1, 2), dtype=float32)
# tf.Tensor(0.763682, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.5672021508216858
# tf.Tensor([[-0.22433166 -0.5608291 ]], shape=(1, 2), dtype=float32)
# tf.Tensor(0.59880054, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.5092460513114929
# tf.Tensor([[-0.21971968 -0.5492991 ]], shape=(1, 2), dtype=float32)
# tf.Tensor(0.43976164, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.4529467225074768
# tf.Tensor([[-0.2117144 -0.529286 ]], shape=(1, 2), dtype=float32)
# tf.Tensor(0.2939819, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.3991132080554962
# tf.Tensor([[-0.20090193 -0.5022548 ]], shape=(1, 2), dtype=float32)
# tf.Tensor(0.1665172, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.3483971357345581
# tf.Tensor([[-0.18789957 -0.4697489 ]], shape=(1, 2), dtype=float32)
# tf.Tensor(0.06022936, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.3012884557247162
# tf.Tensor([[-0.1733255 -0.4333138]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.023934633, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.25811904668807983
# tf.Tensor([[-0.15777165 -0.39442915]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.08658323, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.21907219290733337
# tf.Tensor([[-0.14178157 -0.3544539 ]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.12948844, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.18419761955738068
# tf.Tensor([[-0.12583388 -0.3145847 ]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.15519756, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.1534300148487091
# tf.Tensor([[-0.1103317  -0.27582926]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.16667879, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.1266094297170639
# tf.Tensor([[-0.09559724 -0.23899308]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.16701776, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.10350263863801956
# tf.Tensor([[-0.08187176 -0.20467937]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.1591809, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.08382362872362137
# tf.Tensor([[-0.06931932 -0.17329828]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.14584564, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.06725287437438965
# tf.Tensor([[-0.05803394 -0.14508484]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.12929574, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.05345458537340164
# tf.Tensor([[-0.04804907 -0.12012266]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.111373305, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.042090922594070435
# tf.Tensor([[-0.03934792 -0.09836979]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.093476325, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.03283384069800377
# tf.Tensor([[-0.03187465 -0.07968662]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.07659037, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.025373732671141624
# tf.Tensor([[-0.02554479 -0.06386197]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.061341368, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.01942569576203823
# tf.Tensor([[-0.02025511 -0.05063777]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.048060782, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.014733235351741314
# tf.Tensor([[-0.01589203 -0.03973008]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.036852762, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0
shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 3.882600074778253e-10
# tf.Tensor([[-9.4927399e-10 -2.3731848e-09]], shape=(1, 2), dtype=float32)
# tf.Tensor(1.1707897e-09, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 2.0431396852149675e-10
# tf.Tensor([[-5.0688231e-10 -1.2672057e-09]], shape=(1, 2), dtype=float32)
# tf.Tensor(4.6293325e-10, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 1.0651267368100292e-10
# tf.Tensor([[-2.6807684e-10 -6.7019212e-10]], shape=(1, 2), dtype=float32)
# tf.Tensor(1.4711743e-10, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 5.500913613509795e-11
# tf.Tensor([[-1.4042782e-10 -3.5106953e-10]], shape=(1, 2), dtype=float32)
# tf.Tensor(1.939185e-11, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 2.8144672356567035e-11
# tf.Tensor([[-7.285992e-11 -1.821498e-10]], shape=(1, 2), dtype=float32)
# tf.Tensor(-2.335454e-11, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 1.4265583506145596e-11
# tf.Tensor([[-3.744315e-11 -9.360788e-11]], shape=(1, 2), dtype=float32)
# tf.Tensor(-3.1034703e-11, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 7.1632734466309245e-12
# tf.Tensor([[-1.9059136e-11 -4.7647844e-11]], shape=(1, 2), dtype=float32)
# tf.Tensor(-2.6465094e-11, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 3.5633869986673172e-12
# tf.Tensor([[-9.6091329e-12 -2.4022834e-11]], shape=(1, 2), dtype=float32)
# tf.Tensor(-1.9232373e-11, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 1.756078572487385e-12
# tf.Tensor([[-4.79863241e-12 -1.19965825e-11]], shape=(1, 2), dtype=float32)
# tf.Tensor(-1.2808826e-11, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 8.573425715023564e-13
# tf.Tensor([[-2.3735868e-12 -5.9339669e-12]], shape=(1, 2), dtype=float32)
# tf.Tensor(-8.05527e-12, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 4.1466287868663354e-13
# tf.Tensor([[-1.1629197e-12 -2.9072994e-12]], shape=(1, 2), dtype=float32)
# tf.Tensor(-4.856996e-12, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 1.9868475083489184e-13
# tf.Tensor([[-5.6435396e-13 -1.4108850e-12]], shape=(1, 2), dtype=float32)
# tf.Tensor(-2.8327913e-12, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 9.431159602195024e-14
# tf.Tensor([[-2.712783e-13 -6.781958e-13]], shape=(1, 2), dtype=float32)
# tf.Tensor(-1.6071562e-12, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 4.434998443253631e-14
# tf.Tensor([[-1.2916311e-13 -3.2290777e-13]], shape=(1, 2), dtype=float32)
# tf.Tensor(-8.903028e-13, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 2.0661039407663707e-14
# tf.Tensor([[-6.0915249e-14 -1.5228811e-13]], shape=(1, 2), dtype=float32)
# tf.Tensor(-4.828567e-13, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 9.535448839759816e-15
# tf.Tensor([[-2.845635e-14 -7.114088e-14]], shape=(1, 2), dtype=float32)
# tf.Tensor(-2.568938e-13, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 4.359705261055722e-15
# tf.Tensor([[-1.3167289e-14 -3.2918224e-14]], shape=(1, 2), dtype=float32)
# tf.Tensor(-1.3427263e-13, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 1.974714379713552e-15
# tf.Tensor([[-6.0350822e-15 -1.5087705e-14]], shape=(1, 2), dtype=float32)
# tf.Tensor(-6.902825e-14, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 8.860962538970966e-16
# tf.Tensor([[-2.7399292e-15 -6.8498229e-15]], shape=(1, 2), dtype=float32)
# tf.Tensor(-3.4935633e-14, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 3.939024283159065e-16
# tf.Tensor([[-1.2321622e-15 -3.0804056e-15]], shape=(1, 2), dtype=float32)
# tf.Tensor(-1.7419532e-14, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 1.7346993884773696e-16
# tf.Tensor([[-5.4886666e-16 -1.3721667e-15]], shape=(1, 2), dtype=float32)
# tf.Tensor(-8.562321e-15, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 1.0
# tf.Tensor([[0. 0.]], shape=(1, 2), dtype=float32)
# tf.Tensor(0.0, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.9953246712684631
# tf.Tensor([[-0.03578697 -0.08946736]], shape=(1, 2), dtype=float32)
# tf.Tensor(0.40932494, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.9814295172691345
# tf.Tensor([[-0.07057474 -0.17643672]], shape=(1, 2), dtype=float32)
# tf.Tensor(0.7196809, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.9587005972862244
# tf.Tensor([[-0.10341045 -0.25852594]], shape=(1, 2), dtype=float32)
# tf.Tensor(0.93355155, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.9277616143226624
# tf.Tensor([[-0.13343082 -0.33357736]], shape=(1, 2), dtype=float32)
# tf.Tensor(1.0576673, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.8894455432891846
# tf.Tensor([[-0.15990028 -0.39975092]], shape=(1, 2), dtype=float32)
# tf.Tensor(1.1021707, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.8447571992874146
# tf.Tensor([[-0.18223973 -0.4555995 ]], shape=(1, 2), dtype=float32)
# tf.Tensor(1.0796583, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.7948295474052429
# tf.Tensor([[-0.20004697 -0.50011754]], shape=(1, 2), dtype=float32)
# tf.Tensor(1.0041418, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.7408761978149414
# tf.Tensor([[-0.21310596 -0.532765  ]], shape=(1, 2), dtype=float32)
# tf.Tensor(0.8900484, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.6841428875923157
# tf.Tensor([[-0.22138558 -0.55346394]], shape=(1, 2), dtype=float32)
# tf.Tensor(0.75131893, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.6258605122566223
# tf.Tensor([[-0.22502851 -0.5625713 ]], shape=(1, 2), dtype=float32)
# tf.Tensor(0.6006608, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.5672021508216858
# tf.Tensor([[-0.22433166 -0.5608291 ]], shape=(1, 2), dtype=float32)
# tf.Tensor(0.44899237, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.5092461109161377
# tf.Tensor([[-0.21971965 -0.5492992 ]], shape=(1, 2), dtype=float32)
# tf.Tensor(0.30509788, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.4529467225074768
# tf.Tensor([[-0.2117144 -0.529286 ]], shape=(1, 2), dtype=float32)
# tf.Tensor(0.17547917, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.3991132080554962
# tf.Tensor([[-0.20090193 -0.5022548 ]], shape=(1, 2), dtype=float32)
# tf.Tensor(0.0643971, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.34839701652526855
# tf.Tensor([[-0.18789952 -0.46974885]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.025947183, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.3012884557247162
# tf.Tensor([[-0.1733255 -0.4333138]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.09511897, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.25811904668807983
# tf.Tensor([[-0.15777165 -0.39442915]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.14409205, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.21907222270965576
# tf.Tensor([[-0.14178157 -0.35445395]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.17486668, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.18419761955738068
# tf.Tensor([[-0.12583388 -0.3145847 ]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.19009805, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.1534300148487091
# tf.Tensor([[-0.1103317  -0.27582926]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.1927603, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.1266094297170639
# tf.Tensor([[-0.09559724 -0.23899308]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.18586697, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.10350266098976135
# tf.Tensor([[-0.08187176 -0.20467941]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.17225559, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.08382362872362137
# tf.Tensor([[-0.06931932 -0.17329828]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.1544388, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.06725287437438965
# tf.Tensor([[-0.05803394 -0.14508484]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.13451734, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.05345458537340164
# tf.Tensor([[-0.04804906 -0.12012266]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.11414708, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.042090922594070435
# tf.Tensor([[-0.03934792 -0.09836979]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.0945476, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.03283384069800377
# tf.Tensor([[-0.03187465 -0.07968662]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.076541424, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.025373732671141624
# tf.Tensor([[-0.02554479 -0.06386197]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.060612, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.019425682723522186
# tf.Tensor([[-0.02025509 -0.05063774]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.04697047, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.014733235351741314
# tf.Tensor([[-0.01589203 -0.03973008]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.03562338, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.01107004564255476
# tf.Tensor([[-0.01233875 -0.03084687]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.026435044, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.00824006088078022
# tf.Tensor([[-0.0094807  -0.02370175]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.019181823, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.006076321005821228
# tf.Tensor([[-0.00720966 -0.01802414]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.013595654, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.004438954405486584
# tf.Tensor([[-0.0054265  -0.01356624]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.009397083, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.0032125532161444426
# tf.Tensor([[-0.00404276 -0.01010691]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.006318171, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.002303293440490961
# tf.Tensor([[-0.00298134 -0.00745335]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.0041169142, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.0016359796281903982
# tf.Tensor([[-0.0021764  -0.00544101]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.0025847447, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.001151160802692175
# tf.Tensor([[-0.00157282 -0.00393206]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.0015488574, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.000802460708655417
# tf.Tensor([[-0.00112525 -0.00281312]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.0008710112, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.0005541677819564939
# tf.Tensor([[-0.00079701 -0.00199251]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.00044413807, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.00037912989500910044
# tf.Tensor([[-0.0005589  -0.00139724]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.0001878443, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.0002569592616055161
# tf.Tensor([[-0.00038804 -0.00097009]], shape=(1, 2), dtype=float32)
# tf.Tensor(-4.3585613e-05, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.00017253222176805139
# tf.Tensor([[-0.00026675 -0.00066687]], shape=(1, 2), dtype=float32)
# tf.Tensor(2.9961826e-05, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.0001147641014540568
# tf.Tensor([[-0.00018156 -0.0004539 ]], shape=(1, 2), dtype=float32)
# tf.Tensor(6.1021783e-05, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 7.562596874777228e-05
# tf.Tensor([[-0.00012236 -0.0003059 ]], shape=(1, 2), dtype=float32)
# tf.Tensor(6.818678e-05, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 4.9370300985174254e-05
# tf.Tensor([[-8.1655147e-05 -2.0413788e-04]], shape=(1, 2), dtype=float32)
# tf.Tensor(6.320609e-05, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 3.192931762896478e-05
# tf.Tensor([[-5.395696e-05 -1.348924e-04]], shape=(1, 2), dtype=float32)
# tf.Tensor(5.313483e-05, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 2.0457067876122892e-05
# tf.Tensor([[-3.5305682e-05 -8.8264198e-05]], shape=(1, 2), dtype=float32)
# tf.Tensor(4.1929787e-05, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 1.2984542081539985e-05
# tf.Tensor([[-2.2876138e-05 -5.7190340e-05]], shape=(1, 2), dtype=float32)
# tf.Tensor(3.1589498e-05, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 8.164692189893685e-06
# tf.Tensor([[-1.46780985e-05 -3.66952445e-05]], shape=(1, 2), dtype=float32)
# tf.Tensor(2.2939443e-05, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 5.08606626681285e-06
# tf.Tensor([[-9.3263598e-06 -2.3315899e-05]], shape=(1, 2), dtype=float32)
# tf.Tensor(1.6150487e-05, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 3.1387282888317714e-06
# tf.Tensor([[-5.8683636e-06 -1.4670909e-05]], shape=(1, 2), dtype=float32)
# tf.Tensor(1.1066301e-05, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 1.9189130853192182e-06
# tf.Tensor([[-3.6567153e-06 -9.1417878e-06]], shape=(1, 2), dtype=float32)
# tf.Tensor(7.3984484e-06, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 1.162215880867734e-06
# tf.Tensor([[-2.2565271e-06 -5.6413173e-06]], shape=(1, 2), dtype=float32)
# tf.Tensor(4.834477e-06, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 6.973438075874583e-07
# tf.Tensor([[-1.3790170e-06 -3.4475422e-06]], shape=(1, 2), dtype=float32)
# tf.Tensor(3.0911874e-06, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 4.1451230003985984e-07
# tf.Tensor([[-8.3461350e-07 -2.0865336e-06]], shape=(1, 2), dtype=float32)
# tf.Tensor(1.9354238e-06, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 2.44093456558403e-07
# tf.Tensor([[-5.0025449e-07 -1.2506362e-06]], shape=(1, 2), dtype=float32)
# tf.Tensor(1.1869906e-06, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 1.42398405955646e-07
# tf.Tensor([[-2.9695667e-07 -7.4239171e-07]], shape=(1, 2), dtype=float32)
# tf.Tensor(7.130898e-07, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 8.229700654283079e-08
# tf.Tensor([[-1.7458062e-07 -4.3645156e-07]], shape=(1, 2), dtype=float32)
# tf.Tensor(4.1949306e-07, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 4.711860768225051e-08
# tf.Tensor([[-1.0164913e-07 -2.5412282e-07]], shape=(1, 2), dtype=float32)
# tf.Tensor(2.4148133e-07, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 2.6725777146907603e-08
# tf.Tensor([[-5.8616532e-08 -1.4654134e-07]], shape=(1, 2), dtype=float32)
# tf.Tensor(1.3586774e-07, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 1.5017501908687336e-08
# tf.Tensor([[-3.3477217e-08 -8.3693045e-08]], shape=(1, 2), dtype=float32)
# tf.Tensor(7.4585e-08, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 8.359774206212478e-09
# tf.Tensor([[-1.8936298e-08 -4.7340745e-08]], shape=(1, 2), dtype=float32)
# tf.Tensor(3.9841368e-08, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 4.610220649681196e-09
# tf.Tensor([[-1.0608687e-08 -2.6521720e-08]], shape=(1, 2), dtype=float32)
# tf.Tensor(2.0626167e-08, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 2.518706132548232e-09
# tf.Tensor([[-5.88641402e-09 -1.47160355e-08]], shape=(1, 2), dtype=float32)
# tf.Tensor(1.0284143e-08, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 1.3632101003580033e-09
# tf.Tensor([[-3.2349436e-09 -8.0873592e-09]], shape=(1, 2), dtype=float32)
# tf.Tensor(4.88705e-09, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 7.309344240979954e-10
# tf.Tensor([[-1.7608128e-09 -4.4020321e-09]], shape=(1, 2), dtype=float32)
# tf.Tensor(2.1717035e-09, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 3.882600074778253e-10
# tf.Tensor([[-9.4927399e-10 -2.3731848e-09]], shape=(1, 2), dtype=float32)
# tf.Tensor(8.669675e-10, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 2.0431396852149675e-10
# tf.Tensor([[-5.0688231e-10 -1.2672057e-09]], shape=(1, 2), dtype=float32)
# tf.Tensor(2.7817126e-10, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 1.0651267368100292e-10
# tf.Tensor([[-2.6807684e-10 -6.7019212e-10]], shape=(1, 2), dtype=float32)
# tf.Tensor(3.7019e-11, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 5.500892796828083e-11
# tf.Tensor([[-1.4042728e-10 -3.5106823e-10]], shape=(1, 2), dtype=float32)
# tf.Tensor(-4.5012633e-11, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 2.8144672356567035e-11
# tf.Tensor([[-7.285992e-11 -1.821498e-10]], shape=(1, 2), dtype=float32)
# tf.Tensor(-6.038983e-11, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 1.4265583506145596e-11
# tf.Tensor([[-3.744315e-11 -9.360788e-11]], shape=(1, 2), dtype=float32)
# tf.Tensor(-5.1992723e-11, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 7.1632734466309245e-12
# tf.Tensor([[-1.9059136e-11 -4.7647844e-11]], shape=(1, 2), dtype=float32)
# tf.Tensor(-3.8146247e-11, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 3.5633869986673172e-12
# tf.Tensor([[-9.6091329e-12 -2.4022834e-11]], shape=(1, 2), dtype=float32)
# tf.Tensor(-2.5649326e-11, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 1.756078572487385e-12
# tf.Tensor([[-4.79863241e-12 -1.19965825e-11]], shape=(1, 2), dtype=float32)
# tf.Tensor(-1.628518e-11, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 8.573425715023564e-13
# tf.Tensor([[-2.3735868e-12 -5.9339669e-12]], shape=(1, 2), dtype=float32)
# tf.Tensor(-9.913409e-12, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 4.1466287868663354e-13
# tf.Tensor([[-1.1629197e-12 -2.9072994e-12]], shape=(1, 2), dtype=float32)
# tf.Tensor(-5.8373094e-12, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 1.9868475083489184e-13
# tf.Tensor([[-5.6435396e-13 -1.4108850e-12]], shape=(1, 2), dtype=float32)
# tf.Tensor(-3.3434483e-12, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 9.431159602195024e-14
# tf.Tensor([[-2.712783e-13 -6.781958e-13]], shape=(1, 2), dtype=float32)
# tf.Tensor(-1.8698827e-12, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 4.434998443253631e-14
# tf.Tensor([[-1.2916311e-13 -3.2290777e-13]], shape=(1, 2), dtype=float32)
# tf.Tensor(-1.0238369e-12, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 2.0661039407663707e-14
# tf.Tensor([[-6.0915249e-14 -1.5228811e-13]], shape=(1, 2), dtype=float32)
# tf.Tensor(-5.4992095e-13, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 9.535448839759816e-15
# tf.Tensor([[-2.845635e-14 -7.114088e-14]], shape=(1, 2), dtype=float32)
# tf.Tensor(-2.9018194e-13, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 4.359705261055722e-15
# tf.Tensor([[-1.3167289e-14 -3.2918224e-14]], shape=(1, 2), dtype=float32)
# tf.Tensor(-1.5060525e-13, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 1.974714379713552e-15
# tf.Tensor([[-6.0350822e-15 -1.5087705e-14]], shape=(1, 2), dtype=float32)
# tf.Tensor(-7.695069e-14, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 8.860962538970966e-16
# tf.Tensor([[-2.7399292e-15 -6.8498229e-15]], shape=(1, 2), dtype=float32)
# tf.Tensor(-3.873539e-14, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 3.939024283159065e-16
# tf.Tensor([[-1.2321622e-15 -3.0804056e-15]], shape=(1, 2), dtype=float32)
# tf.Tensor(-1.9221732e-14, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 1.0
# tf.Tensor([[0. 0.]], shape=(1, 2), dtype=float32)
# tf.Tensor(0.0, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.9953246712684631
# tf.Tensor([[-0.03578697 -0.08946736]], shape=(1, 2), dtype=float32)
# tf.Tensor(0.3649351, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.9814295172691345
# tf.Tensor([[-0.07057474 -0.17643672]], shape=(1, 2), dtype=float32)
# tf.Tensor(0.63712287, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.9587005376815796
# tf.Tensor([[-0.10341033 -0.25852615]], shape=(1, 2), dtype=float32)
# tf.Tensor(0.81970394, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.9277616143226624
# tf.Tensor([[-0.13343082 -0.33357736]], shape=(1, 2), dtype=float32)
# tf.Tensor(0.9197208, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.8894455432891846
# tf.Tensor([[-0.15990028 -0.39975092]], shape=(1, 2), dtype=float32)
# tf.Tensor(0.9473111, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.8447571992874146
# tf.Tensor([[-0.18223973 -0.4555995 ]], shape=(1, 2), dtype=float32)
# tf.Tensor(0.9147581, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.7948295474052429
# tf.Tensor([[-0.20004697 -0.50011754]], shape=(1, 2), dtype=float32)
# tf.Tensor(0.8355069, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.7408761978149414
# tf.Tensor([[-0.21310596 -0.532765  ]], shape=(1, 2), dtype=float32)
# tf.Tensor(0.72322047, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.6841428875923157
# tf.Tensor([[-0.22138558 -0.55346394]], shape=(1, 2), dtype=float32)
# tf.Tensor(0.5909367, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.6258605122566223
# tf.Tensor([[-0.22502851 -0.5625713 ]], shape=(1, 2), dtype=float32)
# tf.Tensor(0.4503873, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.5672021508216858
# tf.Tensor([[-0.2243316 -0.5608291]], shape=(1, 2), dtype=float32)
# tf.Tensor(0.31150204, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.5092461109161377
# tf.Tensor([[-0.21971965 -0.5492992 ]], shape=(1, 2), dtype=float32)
# tf.Tensor(0.18211436, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.4529467225074768
# tf.Tensor([[-0.2117144 -0.529286 ]], shape=(1, 2), dtype=float32)
# tf.Tensor(0.06786305, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.39911308884620667
# tf.Tensor([[-0.20090187 -0.5022547 ]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.027742684, shape=(), dtype=float32)
# inputs: (1, 2)
# ...
# tf.Tensor([[-0.13343094 -0.33357716]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.6697598, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.8894456624984741
# tf.Tensor([[-0.15990041 -0.39975077]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.9473101, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.8447573184967041
# tf.Tensor([[-0.18223986 -0.45559934]], shape=(1, 2), dtype=float32)
# tf.Tensor(-1.2561519, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.7948296070098877
# tf.Tensor([[-0.20004709 -0.50011736]], shape=(1, 2), dtype=float32)
# tf.Tensor(-1.5857112, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.7408761978149414
# tf.Tensor([[-0.21310596 -0.532765  ]], shape=(1, 2), dtype=float32)
# tf.Tensor(-1.9238446, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.6841428875923157
# tf.Tensor([[-0.22138558 -0.55346394]], shape=(1, 2), dtype=float32)
# tf.Tensor(-2.2575657, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.6258605122566223
# tf.Tensor([[-0.22502851 -0.5625713 ]], shape=(1, 2), dtype=float32)
# tf.Tensor(-2.5738382, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.5672021508216858
# tf.Tensor([[-0.22433166 -0.5608291 ]], shape=(1, 2), dtype=float32)
# tf.Tensor(-2.8603544, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.5092460513114929
# tf.Tensor([[-0.21971968 -0.5492991 ]], shape=(1, 2), dtype=float32)
# tf.Tensor(-3.1062577, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.4529467225074768
# tf.Tensor([[-0.21171446 -0.529286  ]], shape=(1, 2), dtype=float32)
# tf.Tensor(-3.302745, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 1.0
# tf.Tensor([[0. 0.]], shape=(1, 2), dtype=float32)
# tf.Tensor(0.0, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.9953246712684631
# tf.Tensor([[-0.03578697 -0.08946736]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.121450506, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.9814295172691345
# tf.Tensor([[-0.07057474 -0.17643672]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.29475874, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.9587005972862244
# tf.Tensor([[-0.10341045 -0.25852594]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.5190711, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.9277616739273071
# tf.Tensor([[-0.13343094 -0.33357716]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.79049504, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.8894456624984741
# tf.Tensor([[-0.15990041 -0.39975077]], shape=(1, 2), dtype=float32)
# tf.Tensor(-1.1021696, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.8447573184967041
# tf.Tensor([[-0.18223986 -0.45559934]], shape=(1, 2), dtype=float32)
# tf.Tensor(-1.4445589, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.7948295474052429
# tf.Tensor([[-0.20004697 -0.50011754]], shape=(1, 2), dtype=float32)
# tf.Tensor(-1.8059528, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.7408761978149414
# tf.Tensor([[-0.21310596 -0.532765  ]], shape=(1, 2), dtype=float32)
# tf.Tensor(-2.1731355, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.6841428875923157
# tf.Tensor([[-0.22138558 -0.55346394]], shape=(1, 2), dtype=float32)
# tf.Tensor(-2.5321708, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.6258605122566223
# tf.Tensor([[-0.22502851 -0.5625713 ]], shape=(1, 2), dtype=float32)
# tf.Tensor(-2.86924, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.5672021508216858
# tf.Tensor([[-0.22433166 -0.5608291 ]], shape=(1, 2), dtype=float32)
# tf.Tensor(-3.1714592, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.5092460513114929
# tf.Tensor([[-0.21971968 -0.5492991 ]], shape=(1, 2), dtype=float32)
# tf.Tensor(-3.427627, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 1.0
# tf.Tensor([[0. 0.]], shape=(1, 2), dtype=float32)
# tf.Tensor(0.0, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.9953246712684631
# tf.Tensor([[-0.03578697 -0.08946736]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.14946595, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.9814295172691345
# tf.Tensor([[-0.07057474 -0.17643672]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.3542515, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.9587005972862244
# tf.Tensor([[-0.10341045 -0.25852594]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.6126423, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.9277616739273071
# tf.Tensor([[-0.13343094 -0.33357716]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.9197196, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.8894456624984741
# tf.Tensor([[-0.15990041 -0.39975077]], shape=(1, 2), dtype=float32)
# tf.Tensor(-1.2674811, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.8447571992874146
# tf.Tensor([[-0.18223973 -0.4555995 ]], shape=(1, 2), dtype=float32)
# tf.Tensor(-1.6451957, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.7948295474052429
# tf.Tensor([[-0.20004697 -0.50011754]], shape=(1, 2), dtype=float32)
# tf.Tensor(-2.0399675, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.7408761978149414
# tf.Tensor([[-0.21310596 -0.532765  ]], shape=(1, 2), dtype=float32)
# tf.Tensor(-2.4374704, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.6841428875923157
# tf.Tensor([[-0.22138558 -0.55346394]], shape=(1, 2), dtype=float32)
# tf.Tensor(-2.8227904, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.6258605122566223
# tf.Tensor([[-0.22502851 -0.5625713 ]], shape=(1, 2), dtype=float32)
# tf.Tensor(-3.1813114, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.5672021508216858
# tf.Tensor([[-0.22433166 -0.5608291 ]], shape=(1, 2), dtype=float32)
# tf.Tensor(-3.499574, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 1.0
# tf.Tensor([[0. 0.]], shape=(1, 2), dtype=float32)
# tf.Tensor(0.0, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.9953246712684631
# tf.Tensor([[-0.03578697 -0.08946736]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.1796335, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.9814295172691345
# tf.Tensor([[-0.07057474 -0.17643672]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.41811123, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.9587005972862244
# tf.Tensor([[-0.10341045 -0.25852594]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.71279263, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.9277616739273071
# tf.Tensor([[-0.13343094 -0.33357716]], shape=(1, 2), dtype=float32)
# tf.Tensor(-1.0576658, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.8894455432891846
# tf.Tensor([[-0.15990028 -0.39975092]], shape=(1, 2), dtype=float32)
# tf.Tensor(-1.4435234, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.8447571992874146
# tf.Tensor([[-0.18223973 -0.4555995 ]], shape=(1, 2), dtype=float32)
# tf.Tensor(-1.8583794, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.7948295474052429
# tf.Tensor([[-0.20004697 -0.50011754]], shape=(1, 2), dtype=float32)
# tf.Tensor(-2.288104, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.7408761978149414
# tf.Tensor([[-0.21310596 -0.532765  ]], shape=(1, 2), dtype=float32)
# tf.Tensor(-2.717221, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.6841428875923157
# tf.Tensor([[-0.22138558 -0.55346394]], shape=(1, 2), dtype=float32)
# tf.Tensor(-3.1298096, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.6258605122566223
# tf.Tensor([[-0.22502851 -0.5625713 ]], shape=(1, 2), dtype=float32)
# tf.Tensor(-3.510445, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 1.0
# tf.Tensor([[0. 0.]], shape=(1, 2), dtype=float32)
# tf.Tensor(0.0, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.9953246712684631
# tf.Tensor([[-0.03578697 -0.08946736]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.21201542, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.9814295172691345
# tf.Tensor([[-0.07057474 -0.17643672]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.48646104, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.9587005972862244
# tf.Tensor([[-0.10341045 -0.25852594]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.8197025, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.9277616143226624
# tf.Tensor([[-0.13343082 -0.33357736]], shape=(1, 2), dtype=float32)
# tf.Tensor(-1.2045672, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.8894455432891846
# tf.Tensor([[-0.15990028 -0.39975092]], shape=(1, 2), dtype=float32)
# tf.Tensor(-1.6305745, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.8447571992874146
# tf.Tensor([[-0.18223973 -0.4555995 ]], shape=(1, 2), dtype=float32)
# tf.Tensor(-2.0844283, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.7948295474052429
# tf.Tensor([[-0.20004697 -0.50011754]], shape=(1, 2), dtype=float32)
# tf.Tensor(-2.550712, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.7408761978149414
# tf.Tensor([[-0.21310596 -0.532765  ]], shape=(1, 2), dtype=float32)
# tf.Tensor(-3.0127583, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.6841428875923157
# tf.Tensor([[-0.22138558 -0.55346394]], shape=(1, 2), dtype=float32)
# tf.Tensor(-3.4536152, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 1.0
# tf.Tensor([[0. 0.]], shape=(1, 2), dtype=float32)
# tf.Tensor(0.0, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.9953246712684631
# tf.Tensor([[-0.03578697 -0.08946736]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.24667421, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.9814295172691345
# tf.Tensor([[-0.07057474 -0.17643672]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.55942404, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.9587005376815796
# tf.Tensor([[-0.10341033 -0.25852615]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.9335531, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.9277616143226624
# tf.Tensor([[-0.13343082 -0.33357736]], shape=(1, 2), dtype=float32)
# tf.Tensor(-1.3606544, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.8894455432891846
# tf.Tensor([[-0.15990028 -0.39975092]], shape=(1, 2), dtype=float32)
# tf.Tensor(-1.8289138, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.8447571992874146
# tf.Tensor([[-0.18223973 -0.4555995 ]], shape=(1, 2), dtype=float32)
# tf.Tensor(-2.32366, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.7948295474052429
# tf.Tensor([[-0.20004697 -0.50011754]], shape=(1, 2), dtype=float32)
# tf.Tensor(-2.8281388, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.7408761978149414
# tf.Tensor([[-0.21310596 -0.532765  ]], shape=(1, 2), dtype=float32)
# tf.Tensor(-3.3244536, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 1.0
# tf.Tensor([[0. 0.]], shape=(1, 2), dtype=float32)
# tf.Tensor(0.0, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.9953246712684631
# tf.Tensor([[-0.03578697 -0.08946736]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.2836722, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.9814294576644897
# tf.Tensor([[-0.07057462 -0.17643695]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.6371244, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.9587005376815796
# tf.Tensor([[-0.10341033 -0.25852615]], shape=(1, 2), dtype=float32)
# tf.Tensor(-1.0545223, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.9277616143226624
# tf.Tensor([[-0.13343082 -0.33357736]], shape=(1, 2), dtype=float32)
# tf.Tensor(-1.5261612, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.8894455432891846
# tf.Tensor([[-0.15990028 -0.39975092]], shape=(1, 2), dtype=float32)
# tf.Tensor(-2.0388198, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.8447571992874146
# tf.Tensor([[-0.18223973 -0.4555995 ]], shape=(1, 2), dtype=float32)
# tf.Tensor(-2.5763915, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.7948295474052429
# tf.Tensor([[-0.20004697 -0.50011754]], shape=(1, 2), dtype=float32)
# tf.Tensor(-3.120734, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 1.0
# tf.Tensor([[0. 0.]], shape=(1, 2), dtype=float32)
# tf.Tensor(0.0, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.9953246712684631
# tf.Tensor([[-0.03578685 -0.0894676 ]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.32307327, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.9814294576644897
# tf.Tensor([[-0.07057462 -0.17643695]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.7196826, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.9587005376815796
# tf.Tensor([[-0.10341033 -0.25852615]], shape=(1, 2), dtype=float32)
# tf.Tensor(-1.1827918, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.9277616143226624
# tf.Tensor([[-0.13343082 -0.33357736]], shape=(1, 2), dtype=float32)
# tf.Tensor(-1.7013199, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.8894455432891846
# tf.Tensor([[-0.15990028 -0.39975092]], shape=(1, 2), dtype=float32)
# tf.Tensor(-2.260571, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.8447571992874146
# tf.Tensor([[-0.18223973 -0.4555995 ]], shape=(1, 2), dtype=float32)
# tf.Tensor(-2.8429415, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 1.0
# tf.Tensor([[0. 0.]], shape=(1, 2), dtype=float32)
# tf.Tensor(0.0, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.9953246712684631
# tf.Tensor([[-0.03578697 -0.08946736]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.3649351, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.9814295172691345
# tf.Tensor([[-0.07057474 -0.17643672]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.80722123, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.9587005972862244
# tf.Tensor([[-0.10341045 -0.25852594]], shape=(1, 2), dtype=float32)
# tf.Tensor(-1.3185401, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.9277616739273071
# tf.Tensor([[-0.13343094 -0.33357716]], shape=(1, 2), dtype=float32)
# tf.Tensor(-1.8863611, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.8894456624984741
# tf.Tensor([[-0.15990041 -0.39975077]], shape=(1, 2), dtype=float32)
# tf.Tensor(-2.4944446, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 1.0
# tf.Tensor([[0. 0.]], shape=(1, 2), dtype=float32)
# tf.Tensor(0.0, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.9953246712684631
# tf.Tensor([[-0.03578697 -0.08946736]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.40932494, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.9814295172691345
# tf.Tensor([[-0.07057474 -0.17643672]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.8998667, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.9587005972862244
# tf.Tensor([[-0.10341045 -0.25852594]], shape=(1, 2), dtype=float32)
# tf.Tensor(-1.4619504, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.9277616739273071
# tf.Tensor([[-0.13343094 -0.33357716]], shape=(1, 2), dtype=float32)
# tf.Tensor(-2.0815213, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 1.0
# tf.Tensor([[0. 0.]], shape=(1, 2), dtype=float32)
# tf.Tensor(0.0, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.9953246712684631
# tf.Tensor([[-0.03578697 -0.08946736]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.45630354, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.9814295172691345
# tf.Tensor([[-0.07057474 -0.17643672]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.99774027, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.9587005972862244
# tf.Tensor([[-0.10341045 -0.25852594]], shape=(1, 2), dtype=float32)
# tf.Tensor(-1.6132017, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 1.0
# tf.Tensor([[0. 0.]], shape=(1, 2), dtype=float32)
# tf.Tensor(0.0, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.9953246712684631
# tf.Tensor([[-0.03578697 -0.08946736]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.50593317, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.9814295172691345
# tf.Tensor([[-0.07057474 -0.17643672]], shape=(1, 2), dtype=float32)
# tf.Tensor(-1.1009651, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 1.0
# tf.Tensor([[0. 0.]], shape=(1, 2), dtype=float32)
# tf.Tensor(0.0, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 0.9953246712684631
# tf.Tensor([[-0.03578697 -0.08946736]], shape=(1, 2), dtype=float32)
# tf.Tensor(-0.5582763, shape=(), dtype=float32)
# inputs: (1, 2)
# kernel output: 1.0
# tf.Tensor([[0. 0.]], shape=(1, 2), dtype=float32)
# tf.Tensor(0.0, shape=(), dtype=float32)

# %%
# for i in A:
#     print(i)
input_RHS
# data_points
# tf.square(tf.norm(data_points, ord = 2, axis=1))
# Out:
# <tf.Tensor: shape=(90, 2), dtype=float32, numpy=
# array([[ 4.0000000e+00, -7.8400006e+00],
#        [ 3.9101124e+00, -7.2189927e+00],
#        [ 3.8202248e+00, -6.6283145e+00],
#        [ 3.7303371e+00, -6.0672674e+00],
#        [ 3.6404495e+00, -5.5351553e+00],
#        [ 3.5505619e+00, -5.0312815e+00],
#        [-2.2921348e+00,  5.5153584e-01],
#        [-2.3820224e+00,  7.3329359e-01],
#        [-2.4719100e+00,  9.3352759e-01],
#        [-2.5617979e+00,  1.1529353e+00],
#        [-2.6516855e+00,  1.3922136e+00],
#        [-2.7415731e+00,  1.6520603e+00],
#        [-2.8314607e+00,  1.9331713e+00],
#        [-2.9213483e+00,  2.2362454e+00],
#        [-3.0112360e+00,  2.5619793e+00],
#        [-3.1011236e+00,  2.9110703e+00],
#        [-3.1910112e+00,  3.2842159e+00],
#        [-3.2808988e+00,  3.6821122e+00],
#        [-3.3707864e+00,  4.1054573e+00],
#        [-3.4606740e+00,  4.5549488e+00],
#        [-3.5505619e+00,  5.0312815e+00],
#        [-3.6404495e+00,  5.5351553e+00],
#        [-3.7303371e+00,  6.0672674e+00],
#        [-3.8202248e+00,  6.6283145e+00],
#        [-3.9101124e+00,  7.2189927e+00],
#        [-4.0000000e+00,  7.8400006e+00]], dtype=float32)>

# %%
trial_x = tf.constant([[-1.1, 4.1]], tf.float32)
# trial_x = tf.constant([[0, 0]], tf.float32)
approx = build_lyapunov_function2(trial_x, alphas, n_y, data_points, g_kernel, input_RHS)
approx
# Out:
# <tf.Tensor: shape=(1,), dtype=float32, numpy=array([10652173.], dtype=float32)>

# %%
n_x = 20
x = np.linspace(-bounds[0], bounds[0], n_x)
y = np.linspace(-bounds[1], bounds[1], n_x)

X, Y = np.meshgrid(x, y)

s = X.shape

Ze = np.zeros(s)
Zp = np.zeros(s)
DT = np.zeros((n_x**2,dim))

# convert mesh into point vector for which the model can be evaluated
c = 0
for i in range(s[0]):
    for j in range(s[1]):
        DT[c,0] = X[i,j]
        DT[c,1] = Y[i,j]
        c = c+1;
# define vector field for plot
new_vf = np.reshape(np.array(vf(DT)), (dim, n_x, n_x))

# %%
# solution = np.empty((n_x**2,))


# for ind, i in enumerate(DT):
#     input_x = tf.constant([i], tf.float32)
#     solution[ind] = build_lyapunov_function(input_x, alphas, n_y, data_points, g_kernel, input_RHS)

# %%
solution = build_lyapunov_function2(tf.constant(DT, tf.float32), alphas, n_y, data_points, g_kernel, input_RHS)
solution.shape
# Out:
# TensorShape([400])

# %%
trial_solution = tf.reshape(solution, (n_x, n_x))
plt.figure(figsize=(5,8))
cp = plt.contour(x,y, trial_solution, levels=15)
plt.quiver(X,Y, new_vf[0], new_vf[1], headwidth=2, headlength=4)
plt.clabel(cp, inline=True, fontsize=10)
plt.show()

# %%
solution
# Out:
# <tf.Tensor: shape=(400,), dtype=float32, numpy=
# array([ 18392808.  ,  30047520.  ,  41171408.  ,  50869888.  ,
#         58389316.  ,  63213552.  ,  65120876.  ,  64193228.  ,
#         60779040.  ,  55420904.  ,  48764336.  ,  41465708.  ,
#         34114544.  ,  27180540.  ,  20988118.  ,  15716592.  ,
#         11419352.  ,   8054118.5 ,   5516408.  ,   3670318.5 ,
#        -19093848.  ,  -5780478.  ,   8259399.  ,  21908472.  ,
#         34096336.  ,  43938124.  ,  50839492.  ,  54551240.  ,
#         55167452.  ,  53073072.  ,  48855976.  ,  43203368.  ,
